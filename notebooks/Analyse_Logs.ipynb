# %%
# !python /workspace/mmdetection/tools/analysis_tools/analyze_logs.py plot_curve /out/20250510_065037/vis_data/scalars.json --keys bbox_mAP bbox_mAP_50 bbox_mAP_75 segm_mAP segm_mAP_50 segm_mAP_75 --out ./bbox_mAP.jpg --legend bbox_mAP bbox_mAP_50 bbox_mAP_75 segm_mAP segm_mAP_50 segm_mAP_75
# Out:
# plot curve of /out/20250510_065037/vis_data/scalars.json, metric is bbox_mAP
# plot curve of /out/20250510_065037/vis_data/scalars.json, metric is bbox_mAP_50
# plot curve of /out/20250510_065037/vis_data/scalars.json, metric is bbox_mAP_75
# plot curve of /out/20250510_065037/vis_data/scalars.json, metric is segm_mAP
# plot curve of /out/20250510_065037/vis_data/scalars.json, metric is segm_mAP_50
# plot curve of /out/20250510_065037/vis_data/scalars.json, metric is segm_mAP_75
# save curve to: ./bbox_mAP.jpg

# %%
from IPython.display import Image

# %%
Image("bbox_mAP.jpg")

# %%
# !python /workspace/mmdetection/tools/analysis_tools/analyze_logs.py plot_curve /out/20250510_065037/vis_data/scalars.json --keys lr --out ./lr.jpg --legend lr
# Out:
# plot curve of /out/20250510_065037/vis_data/scalars.json, metric is lr
# save curve to: ./lr.jpg

# %%
Image("lr.jpg")

# %%
#!python /workspace/mmdetection/tools/analysis_tools/browse_dataset.py /out/rtmdet-ins_s_8xb32-50e_coco.py --output-dir ./
